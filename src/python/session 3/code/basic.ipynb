# %%
for i in range(6):
    if i ==3:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
def info_user(nam:str , age : int)-> str: 
    '''
    plaplapla
    Args:
        nam (str): name of user
        age (int): age of user
    Returns: 
        pla pla
    '''
    return f"my name is {nam} {age}"
info_user
print(info_user("osama",33))
# Out:
# my name is osama 33

# %%
def info_user(nam :str | None , age :int | None ): 
    '''
    plaplapla
    Args:
        nam (str): name of user
        age (int): age of user
    Returns: 
        pla pla
    '''
    return f"my name is {nam} {age}"
info_user
print(info_user())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 12
#       8         pla pla
#       9     '''
#      10     return f"my name is {nam} {age}"
#      11 info_user
# ---> 12 print(info_user())
#
# TypeError: info_user() missing 2 required positional arguments: 'nam' and 'age'

# %%
def fun1(age,*name,**plapla):
    for i in name:
        print("\n", i)
        
    print(age)

fun1(15,(1,2,3),depi="osama",oh="plapla")
# Out:
#  (1, 2, 3)
# 15

# %%
def sum(x):
    return x + 10
sum
# Out:
# <function __main__.sum(x)>

# %%
sum
# Out:
# <function __main__.sum(x)>

# %%
def f1(y):
    return lambda x : x+y

f2=f1(10)

print(f2(5))
# Out:
# 15

# %%
transformer = {
    lowerr:lambda text:text.lower(),
    strip: lambda text:text.strip()
}
print(transformer[lowerr](OSAMA))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 transformer = {
# ----> 2     lowerr:lambda text:text.lower(),
#       3     strip: lambda text:text.strip()
#       4 }
#       5 print(transformer[lowerr](OSAMA))
#
# NameError: name 'lowerr' is not defined

# %%
# Out:
# The number 29 is prime.
