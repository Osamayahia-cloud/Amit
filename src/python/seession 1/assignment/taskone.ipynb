# %%
email = "Amit_ml@gmail.edu"
email.find('@')

if (email.count('@')==1 and email.find(".")>email.find("@")):
    print("valid email")
    print(email[email.find('@'):email.rfind("."):1])
    if email.endswith(".com"):
        print("Commercial Domain")
    elif email.endswith(".edu"):
        print("Educational Domain")
    else:
        print("Other Domain")
else:
    print("Invalid email")
# Out:
# valid email
# @gmail
# Educational Domain
