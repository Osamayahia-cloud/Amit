# %%
class student:
    name = "osama"
    age = 22
    
    def std_info(self):
        print (self)

# %%
s1 = student()
print(s1)
print(s1.std_info())
# Out:
# ...
# None

# %%
from abc import ABC,abstractmethod

class Animal(ABC):
    
    def move(self):
        pass


class bird(Animal):
    
    def move(self):
        print("move from bird")



class cat(Animal):
    
    def move(self):
        print("move from cat")

a=bird
a.move()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 22
#      18     def move(self):
#      19         print("move from cat")
#      20
#      21 a=bird
# ---> 22 a.move()
#
# TypeError: bird.move() missing 1 required positional argument: 'self'
