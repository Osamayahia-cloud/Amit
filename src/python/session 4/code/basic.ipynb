# %%
number = 29
    
def isprime(number):
    is_prime = True
    if number <= 1:
        is_prime = False
    else:
        for i in range(2, int(number ** 0.5) + 1):
            if number % i == 0:
                is_prime = False
                break
    return is_prime
if isprime(number):
    print(f"The number {number} is prime.")
else:
    print(f"The number {number} is not prime.")

# %%
def factorial(num : int)->int :
    if num == 0 :
        return 1
    else :
        return num * factorial(num-1)

# %%
def common_divisors(num1:int,num2:int)->list[int]:
    limit = min(num1,num2)
    devisor= []
    for i in range(1,limit+1):
        if num1%i==0 and num1%i==0:
            devisor.append(i)
    return devisor

# %%
def rev(txt)->list[str]:
    lst = txt.split()
    newlist = lst[::-1]
    return newlist

# %%
rev("osama yahia")
# Out:
# ['yahia', 'osama']

# %%
import string,secrets

# %%
import random
def ran(rang:int)->str:
    passw = ""
    character = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    for _ in range(rang):
        passw += random.choice(character)
    return passw

# %%
wordz = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
def coun(words:list)->str:
    unique_words = set(words)
    print(unique_words)
    for word in unique_words:
        woord =dict()
        woord.app{word:words.count(word)}
coun(wordz)
# Out:
# {'No', 'Welcome', 'Hi', 'Ali'}
# 'No:3'

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
unique_words = set(words)
for word in unique_words:
    print (f"{word}:{words.count(word)}")
# Out:
# No:3
# Welcome:1
# Hi:2
# Ali:4

# %%
import random
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}


def get_response(inp):
    for key in responses:
        if key in inp :
            return random.choice(responses[key])
    return random.choice(responses["default"])

# %%
get_response("hello")
# Out:
# 'Hi there!'

# %%
def main(): 
    print("chatbot : can i help you ?")
    while True:
        userinput = input("user :").lower
        response = get_response(userinput)
        print("chatbot:",response)
        if userinput=="goodbye":break
