# %%
import numpy as np

def fact(col,row,values = None):   
    if mode == "zeros":
        return np.zeros(col,row)

    elif mode == "ones":
        return np.ones(col,row)

    elif mode == "full":
        if value is None:
            raise ValueError("Value must be provided for 'full' mode.")
        return np.full((col,row), value)

    elif mode == "identity":
        return np.eye(col,row)

    else:
        raise ValueError("Invalid mode. Choose: zeros, ones, full, identity.")
