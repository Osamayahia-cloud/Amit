# %%
import pandas as pd
def read_file(filepathe):
    return pd.read_csv(filepathe)
df=read_file("Titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
import importlib
import prepr

importlib.reload(prepr)
# Out:
# <module 'prepr' from 'c:\\Users\\Smart\\Desktop\\Amit\\src\\DA\\session 3\\work shop\\prepr.py'>

# %%
from config import cols_drop
from prepr import drop_cols,get_infoo

# %%
df = drop_cols(df,cols_drop)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = drop_cols(df,cols_drop)
#
# File ~\Desktop\Amit\src\DA\session 3\work shop\prepr.py:4, in drop_cols(df, cols)
#       3 def drop_cols(df, cols):
# ----> 4     return df.drop(columns=cols)
#
# File ~\Desktop\Amit\env\Lib\site-packages\pandas\core\frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File ~\Desktop\Amit\env\Lib\site-packages\pandas\core\generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
get_infoo(df)
# Out:
#         PassengerId Survived Pclass Name  Sex      Age  SibSp  Parch Ticket  \
# nunique         891        2      3  891    2       88      7      7    681
# dtype         int64    int64  int64  str  str  float64  int64  int64    str
#
#             Fare Cabin Embarked
# nunique      248   147        3
# dtype    float64   str      str

# %%
null = df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Cabin       3
# Embarked    0
# dtype: int64

# %%
df = df.dropna(subset={"Emparked"})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = df.dropna(subset={"Emparked"})
#
# File ~\Desktop\Amit\env\Lib\site-packages\pandas\core\frame.py:7803, in DataFrame.dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    7799             ax = self._get_axis(agg_axis)
#    7800             indices = ax.get_indexer_for(subset)
#    7801             check = indices == -1
#    7802             if check.any():
# -> 7803                 raise KeyError(np.array(subset)[check].tolist())
#    7804             agg_obj = self.take(indices, axis=agg_axis)
#    7805
#    7806         if thresh is not lib.no_default:
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
df = drop_cols(df,"Pclass")

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
df
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...
